# %% [markdown]
# # __ init __

# %%
import pandas as pd
import pickle
import regex as re

# %%
import pickle
def load_data_from_pickle(filename):
    """
    Load data from a pickle file.
    
    Parameters:
        filename (str): The filename of the pickle file.
        
    Returns:
        The loaded data.
    """
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    print(f"Data loaded from {filename} successfully.")
    return data

# %%
train_data = load_data_from_pickle("train_data.pickle")
# Out:
# Data loaded from train_data.pickle successfully.

# %%
test_data = load_data_from_pickle("test_data.pickle")
# Out:
# Data loaded from test_data.pickle successfully.

# %% [markdown]
# # Model Build

# %% [markdown]
# ## Transformer

# %%
# This code initializes the configuration for spaCy using the 'base_config.cfg' file and fills it with specific train and test file paths,
# creating a customized configuration file named 'config.cfg'. This step is crucial for setting up the spaCy pipeline with the necessary 
# parameters and data paths for training and testing models.

# !python -m spacy init fill-config base_config.cfg config.cfg #open and include train and test file paths
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# If your training data size is 775, and your batch size is 128, you'll have approximately 6 batches per epoch (775 / 128 ≈ 6.05). To ensure you cover the entire dataset for 4 epochs, you'd use the following calculation:
#
# max_steps = batches_per_epoch × max_epochs
#
# max_steps = 6 × 4 = 24

# %%
# This code utilizes spaCy's debugging tool to examine the data specified in the 'config.cfg' configuration file.
# By running the command 'python -m spacy debug data config.cfg', it enables detailed inspection of the data sources,
# annotations, and other 

# !python -m spacy debug data config.cfg
# Out:
# ============================ Data file validation ============================
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Pipeline can be initialized with data
# ✔ Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: transformer, ner
# 775 training docs
# 186 evaluation docs
# ✔ No overlap between training and evaluation data
# ⚠ Low number of examples to train a new pipeline (775)
#
# ============================== Vocab & Vectors ==============================
# ℹ 24759 total word(s) in the data (2703 unique)
# ℹ No word vectors present in the package
#
# ========================== Named Entity Recognition ==========================
# ℹ 7 label(s)
# 0 missing value(s) (tokens with '-' label)
# ✔ Good amount of examples for all labels
# ✔ Examples without occurrences available for all labels
# ✔ No entities consisting of or starting/ending with whitespace
# ✔ No entities crossing sentence boundaries
#
# ================================== Summary ==================================
# ✔ 7 checks passed
# ⚠ 1 warning

# %%
# config.cfg ## replace with a unique config file id
# !python -m spacy train config.cfg --output ./output/spacy/ --paths.train ./train.spacy --paths.dev ./test.spacy
# Out:
# ℹ Saving to output directory: output/spacy
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0        1609.65    821.52    0.12    0.08    0.30    0.00
#  12     200       74842.33  62863.44   83.57   82.05   85.14    0.84
#  24     400       18082.66   9739.88   82.68   80.23   85.29    0.83
# ✔ Saved pipeline to output directory
# output/spacy/model-last

# %% [markdown]
# # Predictions (Test Data)

# %% [markdown]
# ## Load Model

# %%
import spacy
test_nlp = spacy.load('./output/spacy/model-best')

# %%
test_nlp.get_pipe('ner').labels
# Out:
# ('AGE', 'FATALITIES', 'GENDER', 'INJURED', 'REASON', 'TIME', 'VEHICLE TYPE')

# %% [markdown]
# ## Individual Predictions

# %%
entity_names = ["AGE", "VEHICLE TYPE", "REASON", "FATALITIES", "INJURED", "GENDER", "TIME"]

# Define colors for each entity
colors = {entity: "#{}".format(hash(entity) & 0x00FFFFF) for entity in entity_names}


light_colors = {
    "AGE": "#FFDDC1",          # Light orange
    "VEHICLE TYPE": "#D0E1F9", # Light blue
    "REASON": "#FFB6C1",       # Light peach
    "FATALITIES": "#C8E6C9",   # Light green
    "INJURED": "#FFE0B2",      # Light amber
    "GENDER": "#F0F4C3",       # Light yellow
    "TIME": "#E1BEE7"          # Light purple
}

# %%
test = 'A man in his 40s was injured and his mother-in-law seriously injured when their tractor dashed against a tree in this district, police said on Thursday'

# %%
doc = test_nlp(test)

# %%
spacy.displacy.render(doc, style="ent", jupyter=True, options={"colors": light_colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #F0F4C3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENDER</span>
# </mark>
#  in his 40s was injured and his
# <mark class="entity" style="background: #FFDDC1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mother-in-law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  seriously injured when their
# <mark class="entity" style="background: #D0E1F9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tractor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VEHICLE TYPE</span>
# </mark>
#  dashed against a
# <mark class="entity" style="background: #FFB6C1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">REASON</span>
# </mark>
#  in this district, police said on Thursday</div></span>

# %%
test = 'A 40-year-old drunk man was killed and his wife seriously injured when their car dashed against a tree in this district, police said on Thursday'

# %%
doc = test_nlp(test)

# %%
spacy.displacy.render(doc, style="ent", jupyter=True , options={"colors": light_colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #FFDDC1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#
# <mark class="entity" style="background: #FFB6C1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     drunk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">REASON</span>
# </mark>
#
# <mark class="entity" style="background: #F0F4C3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENDER</span>
# </mark>
#  was killed and his
# <mark class="entity" style="background: #F0F4C3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wife
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENDER</span>
# </mark>
#  seriously injured when their
# <mark class="entity" style="background: #D0E1F9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     car
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VEHICLE TYPE</span>
# </mark>
#  dashed against a
# <mark class="entity" style="background: #FFB6C1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">REASON</span>
# </mark>
#  in this district, police said on Thursday</div></span>

# %% [markdown]
# ## Performance Metrics Evaluvation (Test)

# %%
model_name = '' # Add the model name here
description = '''model_name_config_file_$date$time'''

# %%
import pandas as pd

# Initialize lists to store row-wise scores
data_rows = []

# Iterate through test data
for data in test_data:
    true_positives, false_positives, false_negatives = 0, 0, 0  # Reset counts for each data row
    if data is None:
        print("Skipping None value in test data.")
        continue

    text, annotations = data
    doc = test_nlp(text)
    predicted_entities = [(ent.text, ent.label_) for ent in doc.ents]
    true_entities = [(text[start:end], label) for start, end, label in annotations.get('entities', [])]

    # Calculate true positives, false positives, and false negatives for each row
    for entity in predicted_entities:
        if entity in true_entities:
            true_positives += 1
        else:
            false_positives += 1

    for entity in true_entities:
        if entity not in predicted_entities:
            false_negatives += 1

    # Calculate precision, recall, and F1-score for the current row
    row_accuracy = true_positives / (true_positives + false_positives + false_negatives) if (true_positives + false_positives + false_negatives) > 0 else 0
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Append row-wise scores to the data_rows list
    data_rows.append({
        'Text': text,
        'Predicted Entities': predicted_entities,
        'Annotated Entities': true_entities,
        'Accuracy': row_accuracy,
        'Recall': recall,
        'F1-Score': f1
    })

# Create a DataFrame from the data_rows list
df_predicted = pd.DataFrame(data_rows)

# Display the DataFrame
df_predicted.head()
# Out:
#                                                 Text  \
# 0  A Faridabad resident was killed and a youngste...
# 1  A south Mumbai based businessman who was retur...
# 2  A 40-year-old man was killed and his wife seri...
# 3  Five friends celebrating the granting of a vis...
# 4  In a hit-and-run case, a couple and their two ...
#
#                                   Predicted Entities  \
# 0  [(truck, VEHICLE TYPE), (fog, REASON), (car, V...
# 1                            [(businessman, GENDER)]
# 2  [(40-year-old, AGE), (man, GENDER), (wife, GEN...
# 3  [(Five, INJURED), (car, VEHICLE TYPE), (tree, ...
# 4  [(hit-and-run, REASON), (daughters, GENDER), (...
#
#                                   Annotated Entities  Accuracy  Recall  \
# 0  [(truck, VEHICLE TYPE), (driven rashly, REASON...       0.6     0.6
# 1                            [(businessman, GENDER)]       1.0     1.0
# 2  [(40-year-old, AGE), (man, GENDER), (wife, GEN...       1.0     1.0
# 3  [(Five, INJURED), (car, VEHICLE TYPE), (tree, ...       1.0     1.0
# 4  [(hit-and-run, REASON), (five, FATALITIES), (S...       0.8     1.0
#
#    F1-Score
# 0  0.750000
# 1  1.000000
# 2  1.000000
# 3  1.000000
# 4  0.888889

# %% [markdown]
# ## Weighted avg and convert to df above

# %%
from collections import defaultdict
import pandas as pd

# Initialize variables to store true positives, false positives, and false negatives for each entity type
tp = defaultdict(int)
fp = defaultdict(int)
fn = defaultdict(int)
te = defaultdict(int)

# Iterate over the test data
for data in test_data:
    if data is None:
        continue
    
    text, annotations = data
    doc = test_nlp(text)
    predicted_entities = {(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents}
    true_entities = {(start, end, label) for start, end, label in annotations.get('entities', [])}
    
    # Compute true positives, false positives, false negatives, and true entity count
    for ent in predicted_entities:
        if ent in true_entities:
            tp[ent[2]] += 1
        else:
            fp[ent[2]] += 1
    for ent in true_entities:
        if ent not in predicted_entities:
            fn[ent[2]] += 1
        te[ent[2]] += 1  # Increment true entity count for every true entity

# Compute precision, recall, and F1-score for each entity type
precision = {}
recall = {}
f1 = {}
for label in test_nlp.get_pipe('ner').labels:
    precision[label] = tp[label] / (tp[label] + fp[label]) if tp[label] + fp[label] > 0 else 0
    recall[label] = tp[label] / (tp[label] + fn[label]) if tp[label] + fn[label] > 0 else 0
    f1[label] = 2 * (precision[label] * recall[label]) / (precision[label] + recall[label]) if precision[label] + recall[label] > 0 else 0

# Prepare data for DataFrame
data_for_df = []
for label in test_nlp.get_pipe('ner').labels:
    data_for_df.append([label, te[label], round(precision[label], 3), round(recall[label], 3), round(f1[label], 3)])

# Convert to DataFrame
df = pd.DataFrame(data_for_df, columns=['Entity Type', 'Count', 'Precision', 'Recall', 'F1-score'])

# Calculate weighted averages
weighted_precision = (df['Precision'] * df['Count']).sum() / df['Count'].sum()
weighted_recall = (df['Recall'] * df['Count']).sum() / df['Count'].sum()
weighted_f1 = (df['F1-score'] * df['Count']).sum() / df['Count'].sum()

# Add weighted averages to the DataFrame
weighted_averages = pd.DataFrame([['Weighted Average', '', round(weighted_precision, 3), round(weighted_recall, 3), round(weighted_f1, 3)]],
                                 columns=['Entity Type', 'Count', 'Precision', 'Recall', 'F1-score'])
df = pd.concat([df, weighted_averages], ignore_index=True)

df['Model'] = model_name
df.head()
# Out:
#   Entity Type Count  Precision  Recall  F1-score Model
# 0         AGE    71      0.889   0.901     0.895
# 1  FATALITIES    81      0.916   0.938     0.927
# 2      GENDER    67      0.691   0.970     0.807
# 3     INJURED    60      0.824   0.933     0.875
# 4      REASON    89      0.660   0.348     0.456

# %%
## This is used to log
with open(f'macro_metrics_{description}.txt', 'w') as f:
    f.write(captured_output.stdout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 3
#       1 ## This is used to log
#       2 with open(f'macro_metrics_{description}.txt', 'w') as f:
# ----> 3     f.write(captured_output.stdout)
#
# NameError: name 'captured_output' is not defined

# %% [markdown]
# ## Itemized results

# %%
# %%time
# %%capture captured_output

# Initialize lists to store row-wise scores
precision_list, recall_list, f1_list = [], [], []
true_positives, false_positives, false_negatives = 0, 0, 0

# Iterate through test data
for data in test_data:
    true_positives, false_positives, false_negatives = 0, 0, 0  # Reset counts for each data row
    if data is None:
        print("Skipping None value in test data.")
        continue

    text, annotations = data
    doc = test_nlp(text)
    predicted_entities = [(ent.text, ent.label_) for ent in doc.ents]
    true_entities = [(text[start:end], label) for start, end, label in annotations.get('entities', [])]

    # Calculate true positives, false positives, and false negatives for each row
    for entity in predicted_entities:
        if entity in true_entities:
            true_positives += 1
        else:
            false_positives += 1

    for entity in true_entities:
        if entity not in predicted_entities:
            false_negatives += 1

    # Calculate precision, recall, and F1-score for the current row
    row_accuracy = true_positives / (true_positives + false_positives + false_negatives) if (true_positives + false_positives + false_negatives) > 0 else 0
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Append row-wise scores to lists
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

    # Print the results for each row
    print("Text:", text)
    print("Predicted entities:", predicted_entities)
    print("Annotated entities:", true_entities)
    print("Accuracy:", row_accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1)
    print("---------------")

# Calculate accuracy, average precision, recall, and F1-score
accuracy = true_positives / (true_positives + false_positives + false_negatives)
avg_precision = sum(precision_list) / len(precision_list)
avg_recall = sum(recall_list) / len(recall_list)
avg_f1 = sum(f1_list) / len(f1_list)

print("Accuracy:", accuracy)
print("Average Precision:", avg_precision)
print("Average Recall:", avg_recall)
print("Average F1-score:", avg_f1)
# Out:
# Text: A Faridabad resident was killed and a youngster was injured after a truck, allegedly being driven rashly despite dense fog, rammed their car on the Gurugram-Faridabad road in the early hours of Monday
# Predicted entities: [('truck', 'VEHICLE TYPE'), ('fog', 'REASON'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('truck', 'VEHICLE TYPE'), ('driven rashly', 'REASON'), ('fog', 'REASON'), ('car', 'VEHICLE TYPE'), ('early', 'TIME')]
# Accuracy: 0.6
# Precision: 1.0
# Recall: 0.6
# F1-score: 0.7499999999999999
# ---------------
# Text: A south Mumbai based businessman who was returning from a friend's house in Navi Mumbai after an Eid celebration died, while his relative was seriously injured
# Predicted entities: [('businessman', 'GENDER')]
# Annotated entities: [('businessman', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 40-year-old man was killed and his wife seriously injured when their car dashed against a tree in this district, police said on Thursday
# Predicted entities: [('40-year-old', 'AGE'), ('man', 'GENDER'), ('wife', 'GENDER'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON')]
# Annotated entities: [('40-year-old', 'AGE'), ('man', 'GENDER'), ('wife', 'GENDER'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Five friends celebrating the granting of a visa to study abroad to one of them were injured after their car hit a tree and overturned in Sector 50 in the early hours of Thursday
# Predicted entities: [('Five', 'INJURED'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('early', 'TIME')]
# Annotated entities: [('Five', 'INJURED'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('early', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: In a hit-and-run case, a couple and their two minor daughters were among five persons who died after being run over by an SUV in Gwalior district of Madhya Pradesh on Thursday afternoon, police said
# Predicted entities: [('hit-and-run', 'REASON'), ('daughters', 'GENDER'), ('five', 'FATALITIES'), ('SUV', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Annotated entities: [('hit-and-run', 'REASON'), ('five', 'FATALITIES'), ('SUV', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Accuracy: 0.8
# Precision: 0.8
# Recall: 1.0
# F1-score: 0.888888888888889
# ---------------
# Text: Trichy central region police have begun inquiry into the death of two people in separate accidents, including a hit-and-run case, in Pudukottai and Trichy on Monday
# Predicted entities: [('two', 'FATALITIES'), ('hit-and-run', 'REASON')]
# Annotated entities: [('two', 'FATALITIES')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: Three persons sustained serious injuries , while 10 others escaped with minor injuries after the vehicle in which they were travelling rammed the car and toppled near Ladlapur village in Chittapur taluk, Kalaburagi district on Sunday night
# Predicted entities: [('Three', 'INJURED'), ('10', 'INJURED'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('Three', 'INJURED'), ('10', 'INJURED'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: The 8km stretch between the new Katraj tunnel and Navale bridge is turning deadlier by the day, with a 23-year-old motorcyclist losing his life in a hit-and-run case near the new Katraj tunnel around 8am on Wednesday
# Predicted entities: [('23-year-old', 'AGE'), ('hit-and-run', 'REASON'), ('8am', 'TIME')]
# Annotated entities: [('23-year-old', 'AGE'), ('motorcyclist', 'VEHICLE TYPE'), ('hit-and-run', 'REASON'), ('8am', 'TIME')]
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1-score: 0.8571428571428571
# ---------------
# Text: Three youngsters, including a 10-year-old boy, were killed in separate accidents on Friday, said the police
# Predicted entities: [('Three', 'FATALITIES'), ('10-year-old', 'AGE'), ('boy', 'GENDER')]
# Annotated entities: [('Three', 'FATALITIES'), ('10-year-old', 'AGE'), ('boy', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Five persons were killed and 19 others injured in two separate accidents in Dausa, Bharatpur and Bikaner districts on Friday
# Predicted entities: [('Five', 'FATALITIES'), ('19', 'INJURED')]
# Annotated entities: [('Five', 'FATALITIES'), ('19', 'INJURED')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three people died early Sunday morning after a speeding car rammed a parked autorickshaw outside gate number 2 at AIIMS
# Predicted entities: [('Three', 'FATALITIES'), ('morning', 'TIME'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('autorickshaw', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'FATALITIES'), ('morning', 'TIME'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('autorickshaw', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three members of a family were among four people killed on Monday after the car in which they were travelling went out of control and hit a container truck near Thirumangalam in Madurai district
# Predicted entities: [('Three', 'FATALITIES'), ('four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('container truck', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('out of control', 'REASON'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.3333333333333333
# Precision: 0.5
# Recall: 0.5
# F1-score: 0.5
# ---------------
# Text: Even as the public anger against speed demons snuffing out innocent lives on roads continues to rage, a man who was allegedly drunk left five people severely injured by crashing his car into three two-wheelers in the BRTS track on a busy road in the Kapodra area on Sunday night
# Predicted entities: [('speed', 'REASON'), ('man', 'GENDER'), ('drunk', 'REASON'), ('five', 'INJURED'), ('car', 'VEHICLE TYPE'), ('two-wheelers', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('drunk', 'REASON'), ('five', 'INJURED'), ('car', 'VEHICLE TYPE'), ('two-wheelers', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-score: 0.8333333333333333
# ---------------
# Text: Four people of a family were on Sunday killed when their car crashed into a stationary pickup vehicle on Pilibhit-Sitapur highway in Uttar Pradesh , police said
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('pickup vehicle', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('pickup', 'VEHICLE TYPE')]
# Accuracy: 0.25
# Precision: 0.3333333333333333
# Recall: 0.5
# F1-score: 0.4
# ---------------
# Text: A 28-year-old woman was killed and five of her relatives, including two kids, sustained injuries after their car hit a median following a tyre burst on Saturday on Mysuru Road near Ramanagara
# Predicted entities: [('28-year-old', 'AGE'), ('woman', 'GENDER'), ('five', 'INJURED'), ('two', 'INJURED'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('28-year-old', 'AGE'), ('woman', 'GENDER'), ('five', 'INJURED'), ('car', 'VEHICLE TYPE'), ('tyre burst', 'REASON')]
# Accuracy: 0.6666666666666666
# Precision: 0.8
# Recall: 0.8
# F1-score: 0.8000000000000002
# ---------------
# Text: Two persons have lost their lives in separate road accidents in the city in the last two days
# Predicted entities: [('Two', 'FATALITIES')]
# Annotated entities: [('Two', 'FATALITIES')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 14-year-old boy from Kalyan died after the car in which he was travelling with his family fell off a bridge near Malshej ghat, near Kalyan, in Thane district, on Sunday
# Predicted entities: [('14-year-old', 'AGE'), ('boy', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('14-year-old', 'AGE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.6666666666666666
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-score: 0.8
# ---------------
# Text: Two persons were killed and one injured after the utility vehicle they were travelling in fell into a deep gorge near Chharba village in Vikasnagar block of Dehradun district on Monday morning
# Predicted entities: [('Two', 'FATALITIES'), ('one', 'INJURED'), ('utility vehicle', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('Two', 'FATALITIES'), ('one', 'INJURED'), ('utility', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: A case has been registered against the assistant sub-inspector (ASI) of Delhi police after a car he was travelling rammed into six vehicles in Delhi's Dwarka Mor area on last Tuesday night
# Predicted entities: [('car', 'VEHICLE TYPE'), ('he', 'GENDER'), ('night', 'TIME')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-score: 0.8
# ---------------
# Text: Seven kanwariyas, three from Haryana's Mahendergarh district, two from Kaithal district, and one from Jind district and one from Punjab's Ludhiana district, were killed in three accidents on Friday
# Predicted entities: [('Seven', 'FATALITIES'), ('two', 'FATALITIES')]
# Annotated entities: [('Seven', 'FATALITIES')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: Four people, including a six-year-old girl, were killed in a road accident in the Palia area of Lakhimpur Kheri district on Thursday afternoon, police said
# Predicted entities: [('Four', 'FATALITIES'), ('six-year-old', 'AGE'), ('girl', 'GENDER'), ('afternoon', 'TIME')]
# Annotated entities: [('Four', 'FATALITIES'), ('a six-year-old', 'AGE'), ('girl', 'GENDER'), ('afternoon', 'TIME')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: Two men, including a businessman, died and three people were injured after their car rammed into a stationary truck in Swaroop Nagar in Outer-North district on Sunday morning
# Predicted entities: [('Two', 'FATALITIES'), ('men', 'GENDER'), ('businessman', 'GENDER'), ('three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('Two', 'FATALITIES'), ('three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-score: 0.8333333333333333
# ---------------
# Text: A 50-year-old assistant review officer died in a road accident which took place in Lucknows Hussainganj police station area on Tuesday afternoon
# Predicted entities: [('50-year-old', 'AGE'), ('afternoon', 'TIME')]
# Annotated entities: [('50-year-old', 'AGE'), ('afternoon', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 30-year-old Delhi resident was killed and her husband was injured after a truck allegedly rammed into their car near Farrukhnagar toll plaza, police said on Friday
# Predicted entities: [('30-year-old', 'AGE'), ('husband', 'GENDER'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('30-year-old', 'AGE'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 0.75
# Recall: 1.0
# F1-score: 0.8571428571428571
# ---------------
# Text: A 49-year-old man was killed in an accident after his bike collided with a mini-truck near Kakkanad on Tuesday
# Predicted entities: [('49-year-old', 'AGE'), ('man', 'GENDER'), ('bike', 'VEHICLE TYPE'), ('mini-truck', 'VEHICLE TYPE')]
# Annotated entities: [('49-year-old', 'AGE'), ('bike', 'VEHICLE TYPE'), ('mini-truck', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 0.75
# Recall: 1.0
# F1-score: 0.8571428571428571
# ---------------
# Text: A 40-year-old man who had stepped out of his car to check if he and his friends were moving in the right direction was mowed down by an SUV on the Delhi-Mumbai expressway early on Sunday
# Predicted entities: [('40-year-old', 'AGE'), ('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('SUV', 'VEHICLE TYPE')]
# Annotated entities: [('40-year-old', 'AGE'), ('car', 'VEHICLE TYPE'), ('SUV', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 0.75
# Recall: 1.0
# F1-score: 0.8571428571428571
# ---------------
# Text: An accident claimed the life of a 15-year-old boy in Sargasan on Tuesday afternoon
# Predicted entities: [('15-year-old', 'AGE'), ('boy', 'GENDER'), ('afternoon', 'TIME')]
# Annotated entities: [('15-year-old', 'AGE'), ('afternoon', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-score: 0.8
# ---------------
# Text: Four people, including a cleric (imam) were killed when a car they were travelling in skidded off the road and rolled into a gorge on the Jammu-Srinagar national highway in Udhampur district, on Monday
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two people died while four sustained injuries after an SUV rammed into a road-roller moving on the Pune-Bengaluru National Highway near Ghunki phata in Kolhapur district on Saturday morning
# Predicted entities: [('Two', 'FATALITIES'), ('four', 'INJURED'), ('SUV', 'VEHICLE TYPE'), ('road-roller', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('Two', 'FATALITIES'), ('four', 'INJURED'), ('morning', 'TIME')]
# Accuracy: 0.6
# Precision: 0.6
# Recall: 1.0
# F1-score: 0.7499999999999999
# ---------------
# Text: The video of a girl student being tossed into the air and falling 15 feet away after being hit by a speeding Jaguar car in Raichuru has gone viral
# Predicted entities: [('girl', 'GENDER'), ('speeding', 'REASON'), ('Jaguar car', 'VEHICLE TYPE')]
# Annotated entities: [('girl', 'GENDER'), ('speeding', 'REASON'), ('Jaguar car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: An unidentified man, around 40, years old died after he was knocked down by an allegedly speeding car near Thane’s Upvan area late on Wednesday
# Predicted entities: [('man', 'GENDER'), ('40', 'AGE'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('man', 'GENDER'), ('40', 'AGE'), ('speeding', 'REASON'), ('late', 'TIME')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: Five people were killed and 43 persons were injured in a road accident involving a mofussil bus of Tamil Nadu State Transport Corporation (TNSTC) and a car on the Trichy-Dindigul national highway (NH) near Manapparai in Trichy district on Sunday evening
# Predicted entities: [('Five', 'FATALITIES'), ('43', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('evening', 'TIME')]
# Annotated entities: [('Five', 'FATALITIES'), ('43', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('evening', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 19-year-old youth was killed and another injured after a speeding car allegedly rammed their motorcycle on Sohna Road
# Predicted entities: [('19-year-old', 'AGE'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('motorcycle', 'VEHICLE TYPE')]
# Annotated entities: [('19-year-old', 'AGE'), ('speeding', 'REASON')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: Three days after a man hit a woman while driving his car and sped away, the police arrested Jay Patel , a resident of Vadsar area, after a video of the accident went viral
# Predicted entities: [('man', 'GENDER'), ('woman', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('man', 'GENDER'), ('woman', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: One of the Tamil Nadu tourists involved in the car accident at Calangute on Saturday morning died at Goa Medical College, Bambolim, on Sunday
# Predicted entities: [('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 31-year-old man was killed and four others were injured after their car was hit by an unidentified vehicle on the Jaipur-Agra highway under Bassi police station area of Jaipur Sunday morning
# Predicted entities: [('31-year-old', 'AGE'), ('man', 'GENDER'), ('four', 'INJURED'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('31-year-old', 'AGE'), ('man', 'GENDER'), ('four', 'INJURED'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two persons died in separate hit-and-run accidents in 24 hours ending on Monday in Rajkot
# Predicted entities: [('Two', 'FATALITIES'), ('hit-and-run', 'REASON')]
# Annotated entities: [('Two', 'FATALITIES'), ('hit-and-run', 'REASON')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A dentist returning to Dausa from Jaipur was killed and his colleague was seriously injured when their car rammed into a tractor carrying iron rods near Transport Nagar here in the intervening night of Sunday and Monday
# Predicted entities: [('car', 'VEHICLE TYPE'), ('tractor', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('tractor', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two people were killed and three others sustained injuries after their car lost balance and fell into a gorge on Delhi-Lucknow national highway on Saturday
# Predicted entities: [('Two', 'FATALITIES'), ('three', 'INJURED'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('three', 'INJURED'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: At least six persons died and one sustained injuries in a ghastly road accident reported near Srikalahasti in the district on Sunday
# Predicted entities: [('six', 'FATALITIES'), ('one', 'INJURED')]
# Annotated entities: [('six', 'FATALITIES'), ('one', 'INJURED')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Within a span of 24 hours, four persons were killed, two others were injured while several vehicles were damaged in two separate road accidents in Shimla district
# Predicted entities: [('four', 'FATALITIES'), ('two', 'INJURED')]
# Annotated entities: [('four', 'FATALITIES'), ('two', 'INJURED')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three men were killed after their bike on which they were travelling collided head-on with a car in the Kakopathar area of Tinsukia district on Saturday night
# Predicted entities: [('Three', 'FATALITIES'), ('men', 'GENDER'), ('bike', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('bike', 'VEHICLE TYPE'), ('head-on', 'REASON'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 0.8
# Recall: 0.8
# F1-score: 0.8000000000000002
# ---------------
# Text: Five persons, including four of the same family, were killed after their car plunged into a swollen canal in Uttar Pradesh's Etah district on Monday
# Predicted entities: [('Five', 'FATALITIES'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Five', 'FATALITIES'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 25-year-old man who stepped out of his car parked on NH-9 died after a truck crashed into the vehicle from behind early on Sunday
# Predicted entities: [('25-year-old', 'AGE'), ('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('25-year-old', 'AGE'), ('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('early', 'TIME')]
# Accuracy: 0.8
# Precision: 1.0
# Recall: 0.8
# F1-score: 0.888888888888889
# ---------------
# Text: Five persons died on the spot and eight others received severe injuries in a road accident in the early hours of Saturday at Madiki village of Alamuru mandal in Konaseema district
# Predicted entities: [('Five', 'FATALITIES'), ('eight', 'INJURED')]
# Annotated entities: [('Five', 'FATALITIES'), ('eight', 'INJURED'), ('early', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-score: 0.8
# ---------------
# Text: Two people were killed in a road accident , near the Dhola-Sadiya bridge , in Tinsukia on Wednesday
# Predicted entities: [('Two', 'FATALITIES')]
# Annotated entities: [('Two', 'FATALITIES')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four persons returning from a funeral were killed in an accident on the Samruddhi expressway in Aurangabad district on Wednesday, an official said
# Predicted entities: [('Four', 'FATALITIES')]
# Annotated entities: [('Four', 'FATALITIES')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four people were killed and four others sustained injuries in two separate road accidents in Thanjavur and Pudukottai on Wednesday
# Predicted entities: [('Four', 'FATALITIES'), ('four', 'INJURED')]
# Annotated entities: [('Four', 'FATALITIES'), ('four', 'INJURED')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A pedestrian died while another sustained severe injuries after being mowed down by a car on Alagappa Road in Kilpauk on Wednesday
# Predicted entities: [('car', 'VEHICLE TYPE')]
# Annotated entities: [('mowed', 'REASON'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.5
# Precision: 1.0
# Recall: 0.5
# F1-score: 0.6666666666666666
# ---------------
# Text: Two people were killed while four others were injured after a speeding car crashed into another stationary car on the Yamuna Expressway in UP’s Mathura
# Predicted entities: [('Two', 'FATALITIES'), ('four', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('four', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four members of a family, including two women, died while another member was severely injured when the car they were travelling in skidded off NH-315 and crashed into a tree in Assam ’s Tinsukia district early Friday
# Predicted entities: [('Four', 'FATALITIES'), ('women', 'GENDER'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('early', 'TIME')]
# Annotated entities: [('Four', 'FATALITIES'), ('women', 'GENDER'), ('car', 'VEHICLE TYPE'), ('skidded', 'REASON'), ('early', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 0.8
# Recall: 0.8
# F1-score: 0.8000000000000002
# ---------------
# Text: A 19-year-old BTech student has been arrested on charges of ramming his car into an auto while in an inebriated condition, killing its driver on the spot, near Devanahalli late on Wednesday night
# Predicted entities: [('19-year-old', 'AGE'), ('car', 'VEHICLE TYPE'), ('auto', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('19-year-old', 'AGE'), ('car', 'VEHICLE TYPE'), ('auto', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: At least three people were killed while two others suffered injuries in a road mishap reported near Yerpedu in Tirupati district early on Thursday morning
# Predicted entities: [('three', 'FATALITIES'), ('two', 'INJURED'), ('morning', 'TIME')]
# Annotated entities: [('three', 'FATALITIES'), ('two', 'INJURED'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: In a futile attempt to flee from a police vehicle, a murder accused grabbed the driver and pulled on the steering wheel on Monday
# Predicted entities: []
# Annotated entities: [('pulled', 'REASON'), ('steering', 'REASON'), ('wheel', 'REASON')]
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1-score: 0
# ---------------
# Text: Five members of a family, including three children, were killed after a container truck coming from the wrong side of the road rammed into their car in Pune district of Maharashtra early on Wednesday, police said
# Predicted entities: [('Five', 'FATALITIES'), ('container truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('early', 'TIME')]
# Annotated entities: [('three', 'FATALITIES'), ('wrong side', 'REASON'), ('car', 'VEHICLE TYPE'), ('early', 'TIME')]
# Accuracy: 0.3333333333333333
# Precision: 0.5
# Recall: 0.5
# F1-score: 0.5
# ---------------
# Text: Two women and a man died, and four other people were injured, when a Bolero SUV car they were travelling in lost control and overturned in Binjrad police station area of Barmer district on Monday
# Predicted entities: [('Two', 'FATALITIES'), ('women', 'GENDER'), ('man', 'GENDER'), ('four', 'INJURED'), ('Bolero SUV', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('women', 'GENDER'), ('man', 'GENDER'), ('four', 'INJURED'), ('Bolero', 'VEHICLE TYPE'), ('SUV', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('lost control', 'REASON')]
# Accuracy: 0.5555555555555556
# Precision: 0.8333333333333334
# Recall: 0.625
# F1-score: 0.7142857142857143
# ---------------
# Text: A 22-year-old bank cashier died after the bike he was riding was hit by a car in Vivek Vihar in Shahdara district on Wednesday
# Predicted entities: [('22-year-old', 'AGE'), ('bike', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('22-year-old', 'AGE'), ('bike', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 42-year-old bank manager died and four people, including three from his family and the driver, were injured after their car rammed into a stationary mini-truck from behind on NH-9 near Pandav Nagar on Sunday
# Predicted entities: [('42-year-old', 'AGE'), ('four', 'INJURED'), ('three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('mini-truck', 'VEHICLE TYPE')]
# Annotated entities: [('42-year-old', 'AGE'), ('four', 'INJURED'), ('car', 'VEHICLE TYPE'), ('mini-truck', 'VEHICLE TYPE')]
# Accuracy: 0.8
# Precision: 0.8
# Recall: 1.0
# F1-score: 0.888888888888889
# ---------------
# Text: Eight persons, two of them kids, were injured in two separate accidents on the Yamuna Expressway early on Monday as dense fog cut down visibility to a few metres on the high-speed corridor
# Predicted entities: [('Eight', 'INJURED'), ('fog', 'REASON')]
# Annotated entities: [('Eight', 'INJURED'), ('early', 'TIME'), ('fog', 'REASON')]
# Accuracy: 0.6666666666666666
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-score: 0.8
# ---------------
# Text: A 45-year-old woman who worked at an MNC in DLF 5 died in a road accident near Westend Heights on Tuesday night when the Rapido bike she was on was hit by a car
# Predicted entities: [('45-year-old', 'AGE'), ('woman', 'GENDER'), ('night', 'TIME'), ('Rapido bike', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('45-year-old', 'AGE'), ('night', 'TIME'), ('bike', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.5
# Precision: 0.6
# Recall: 0.75
# F1-score: 0.6666666666666665
# ---------------
# Text: A 31-year-old woman from Kalyan was killed after her car crashed into the metal railing on the median on the Mumbai-Pune expressway near Khopoli exit around 12 noon Saturday
# Predicted entities: [('31-year-old', 'AGE'), ('woman', 'GENDER'), ('car', 'VEHICLE TYPE'), ('noon', 'TIME')]
# Annotated entities: [('31-year-old', 'AGE'), ('car', 'VEHICLE TYPE'), ('noon', 'TIME')]
# Accuracy: 0.75
# Precision: 0.75
# Recall: 1.0
# F1-score: 0.8571428571428571
# ---------------
# Text: In a double tragedy, a mother and son died in accidents barely 12 hours apart in Madhya Pradesh
# Predicted entities: [('mother', 'GENDER'), ('son', 'GENDER')]
# Annotated entities: [('mother', 'GENDER'), ('son', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 32-year-old motorcyclist was killed when he rammed into a stationary dumper parked in the middle of the highway on LBS Marg in Mulund on Saturday
# Predicted entities: [('32-year-old', 'AGE'), ('dumper', 'VEHICLE TYPE')]
# Annotated entities: [('32-year-old', 'AGE')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: Two people were killed in separate incidents at Thiruvottiyur and Thirumullaivoyal
# Predicted entities: [('Two', 'FATALITIES')]
# Annotated entities: [('Two', 'FATALITIES')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three employees of a top Indian IT firm and a driver were severely injured when the office car they were travelling in rammed in to a stationary sand laden truck
# Predicted entities: [('Three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two people, including a 17-year-old girl, died in two separate road accidents in the district on Tuesday
# Predicted entities: [('Two', 'FATALITIES'), ('17-year-old', 'AGE'), ('girl', 'GENDER')]
# Annotated entities: [('Two', 'FATALITIES'), ('17-year-old', 'AGE'), ('girl', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A woman and her grandson were killed in a collision between a pick-up vehicle and a car near the light point of Chatt in the early hours of Saturday
# Predicted entities: [('woman', 'GENDER'), ('grandson', 'GENDER'), ('pick-up', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('woman', 'GENDER'), ('grandson', 'GENDER'), ('collision', 'REASON'), ('pick-up', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('early', 'TIME')]
# Accuracy: 0.6666666666666666
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-score: 0.8
# ---------------
# Text: Four people, including three members of a family from Delhi, were killed when the car in which they were travelling crashed into a tree amid dense fog in Uttar Pradesh's Kasganj district on Saturday evening
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('fog', 'REASON'), ('evening', 'TIME')]
# Annotated entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('fog', 'REASON'), ('evening', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A man was killed in an accident at Perumbavoor after the car he was travelling in rammed a truck that was parked along the road on Wednesday morning
# Predicted entities: [('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three bikers were killed in two accidents in Nashik city and Chandwad on Sunday
# Predicted entities: [('Three', 'FATALITIES'), ('bikers', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'FATALITIES'), ('bikers', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two friends, who were sitting on a footpath, were crushed to death by a speeding car that was driven by a 16-year-old boy in Jetpur town of Rajkot district
# Predicted entities: [('Two', 'FATALITIES'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('16-year-old', 'AGE'), ('boy', 'GENDER')]
# Annotated entities: [('Two', 'FATALITIES'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('16-year-old', 'AGE')]
# Accuracy: 0.8
# Precision: 0.8
# Recall: 1.0
# F1-score: 0.888888888888889
# ---------------
# Text: A 25-year-old man died while two others were injured when their speeding car went out of control and crashed into a tree in the Beta-2 area of Greater Noida on Monday morning
# Predicted entities: [('25-year-old', 'AGE'), ('man', 'GENDER'), ('two', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON'), ('morning', 'TIME')]
# Annotated entities: [('25-year-old', 'AGE'), ('two', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-score: 0.8333333333333333
# ---------------
# Text: Five people were killed and another was injured when a speeding car crashed into two stationary trucks in the Sadar police station area of Tonk district , police said on Monday
# Predicted entities: [('Five', 'FATALITIES'), ('another', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('trucks', 'VEHICLE TYPE')]
# Annotated entities: [('Five', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('trucks', 'VEHICLE TYPE')]
# Accuracy: 0.6
# Precision: 0.6
# Recall: 1.0
# F1-score: 0.7499999999999999
# ---------------
# Text: A constable of the crime branch team of Jankipuram police in Lucknow suffered injuries after a car-borne youth hit him to avoid car checking on Sunday
# Predicted entities: [('car', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('car-borne', 'VEHICLE TYPE'), ('avoid car checking', 'REASON')]
# Accuracy: 0.0
# Precision: 0.0
# Recall: 0.0
# F1-score: 0
# ---------------
# Text: Samajwadi Party leader Devendra Singh Yadav from Uttar Pradesh had a narrow escape after his car was hit by a truck in Mainpuri on Sunday night
# Predicted entities: [('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two young students hailing from Hyderabad were killed in a road accident in Saudi Arabia ’s Dammam on June 13
# Predicted entities: [('Two', 'FATALITIES')]
# Annotated entities: [('Two', 'FATALITIES')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three people were killed and two others injured when their car lost balance, overturned and fell into a roadside ditch after hitting a truck in Jaunpur district, police said on Wednesday
# Predicted entities: [('Three', 'FATALITIES'), ('two', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'FATALITIES'), ('two', 'INJURED'), ('lost balance', 'REASON'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: An autorickshaw driver and passenger died and two others were grievously injured in a hit-and-run at Goregaon (east) early on Thursday
# Predicted entities: [('autorickshaw', 'VEHICLE TYPE'), ('two', 'INJURED'), ('hit-and-run', 'REASON')]
# Annotated entities: [('autorickshaw', 'VEHICLE TYPE'), ('two', 'INJURED'), ('hit-and-run', 'REASON'), ('early', 'TIME')]
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1-score: 0.8571428571428571
# ---------------
# Text: Two policemen, who were on night patrolling duty in Dehlon area on Monday, sustained injuries after an unidentified speeding car hit their bike
# Predicted entities: [('Two', 'INJURED'), ('policemen', 'GENDER'), ('night', 'TIME'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('bike', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('bike', 'VEHICLE TYPE')]
# Accuracy: 0.6666666666666666
# Precision: 0.6666666666666666
# Recall: 1.0
# F1-score: 0.8
# ---------------
# Text: In a freak mishap, a container truck, a loaded trailer and a car collided near Gaikmukh and led to a major traffic jam on the Mumbai-bound lane of Ghodbunder Road and Ahmedabad highway on Tuesday morning, officials informed
# Predicted entities: [('truck', 'VEHICLE TYPE'), ('trailer', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('truck', 'VEHICLE TYPE'), ('trailer', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Three persons were injured in a car accident at the PVNR Expressway on Sunday afternoon
# Predicted entities: [('Three', 'INJURED'), ('car', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Accuracy: 0.5
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1-score: 0.6666666666666666
# ---------------
# Text: Two motorcycle riders were killed in two different road accidents in Mohali
# Predicted entities: [('Two', 'FATALITIES'), ('motorcycle', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('motorcycle', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Thane-bound traffic on Ghodbunder road was affected for nearly two hours on Tuesday morning after an accident involving a truck and a four wheeler
# Predicted entities: [('morning', 'TIME'), ('truck', 'VEHICLE TYPE'), ('four wheeler', 'VEHICLE TYPE')]
# Annotated entities: [('morning', 'TIME'), ('truck', 'VEHICLE TYPE'), ('four wheeler', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 71-year-old man died in a road accident when a speeding car hit his motorcycle
# Predicted entities: [('71-year-old', 'AGE'), ('man', 'GENDER'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('motorcycle', 'VEHICLE TYPE')]
# Annotated entities: [('71-year-old', 'AGE'), ('man', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.6
# Precision: 0.6
# Recall: 1.0
# F1-score: 0.7499999999999999
# ---------------
# Text: A 80-year-old man and his sons were killed after their car was hit by an unidentified vehicle in Narsinghpur district on Sunday night
# Predicted entities: [('80-year-old', 'AGE'), ('man', 'GENDER'), ('sons', 'GENDER'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('80-year-old', 'AGE'), ('man', 'GENDER'), ('sons', 'GENDER'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A woman and her two minor sons were killed while three people sustained injuries when a bus rammed into a car and a minibus in Bhilwara district, said police on Monday
# Predicted entities: [('woman', 'GENDER'), ('two', 'FATALITIES'), ('sons', 'GENDER'), ('three', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('minibus', 'VEHICLE TYPE')]
# Annotated entities: [('woman', 'GENDER'), ('sons', 'GENDER'), ('three', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.7142857142857143
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-score: 0.8333333333333333
# ---------------
# Text: In a drunk driving incident near Breach Candy on Monday, Raunak Ganatra, 26, rammed into a taxi driver walking out to grab a bite and after losing further control, slammed into two taxis and a brown sedan, parked by the road
# Predicted entities: [('drunk', 'REASON'), ('26', 'AGE'), ('taxis', 'VEHICLE TYPE'), ('sedan', 'VEHICLE TYPE')]
# Annotated entities: [('drunk', 'REASON'), ('26', 'AGE'), ('taxis', 'VEHICLE TYPE'), ('sedan', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: At least two women were killed and four others sustained serious injuries in a collision between a car and a truck in Ghazipur on Saturday
# Predicted entities: [('two', 'FATALITIES'), ('women', 'GENDER'), ('four', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('two', 'FATALITIES'), ('women', 'GENDER'), ('four', 'INJURED'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A youth died and another was injured after colliding with the vehicle of a serving colonel in at Ridge Road, under the Gorabazar police station, in Jabalpur on Saturday
# Predicted entities: []
# Annotated entities: [('youth', 'AGE'), ('colliding', 'REASON')]
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1-score: 0
# ---------------
# Text: One person was killed and 11 injured in an accident involving two tractor trolleys , a passenger bus and a car at Bheru ghat in Simrol on late Monday night
# Predicted entities: [('One', 'FATALITIES'), ('11', 'INJURED'), ('tractor', 'VEHICLE TYPE'), ('trolleys', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('One', 'FATALITIES'), ('11', 'INJURED'), ('tractor', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('late', 'TIME'), ('night', 'TIME')]
# Accuracy: 0.75
# Precision: 0.8571428571428571
# Recall: 0.8571428571428571
# F1-score: 0.8571428571428571
# ---------------
# Text: Three persons, including two minors died and three others injured after a speeding car in which they were travelling rammed into a roadside electric pole on the Maurawan-Gurbaksh Ganj road in Unnao district on Saturday night
# Predicted entities: [('Three', 'FATALITIES'), ('two', 'FATALITIES'), ('three', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('minors', 'AGE'), ('three', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# F1-score: 0.8333333333333334
# ---------------
# Text: Three persons, including two women, were killed when their car hurtled off a bridge in Ghatabillod area of Dhar district on Tuesday evening
# Predicted entities: [('Three', 'FATALITIES'), ('women', 'GENDER'), ('car', 'VEHICLE TYPE'), ('evening', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('women', 'GENDER'), ('hurtled', 'REASON'), ('evening', 'TIME')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: Four members of a family were killed when their car overturned due to tyre burst at Mupkal in Telangana's Nizamabad district on Wednesday
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('tyre burst', 'REASON')]
# Accuracy: 0.6666666666666666
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-score: 0.8
# ---------------
# Text: Two Jammu University students died and as many were injured on Monday when their car rolled down a deep gorge after being hit by a truck on the Jammu-Srinagar national highway in Ramban district, officials said
# Predicted entities: [('Two', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A Class 2 student died after a car on the wrong side of a road hit a scooter that her father was driving to drop her to school on Thursday morning in Sector 22
# Predicted entities: [('car', 'VEHICLE TYPE'), ('scooter', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('Class 2', 'AGE'), ('car', 'VEHICLE TYPE'), ('wrong side', 'REASON'), ('scooter', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 0.6
# Precision: 1.0
# Recall: 0.6
# F1-score: 0.7499999999999999
# ---------------
# Text: A Class II student died after a car on the wrong side of a road hit a scooter that her father was driving to drop her to school on Thursday morning in Sector 22
# Predicted entities: [('car', 'VEHICLE TYPE'), ('scooter', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('Class II', 'AGE'), ('car', 'VEHICLE TYPE'), ('wrong side', 'REASON'), ('scooter', 'VEHICLE TYPE'), ('her', 'GENDER'), ('morning', 'TIME')]
# Accuracy: 0.5
# Precision: 1.0
# Recall: 0.5
# F1-score: 0.6666666666666666
# ---------------
# Text: A 56-year-old woman from Delhi died and four of her family members suffered injuries when the Swift Dzire in which they were travelling collided head-on with a car being driven on the wrong side of the Dwarka Expressway
# Predicted entities: [('56-year-old', 'AGE'), ('woman', 'GENDER'), ('four', 'INJURED'), ('Swift Dzire', 'VEHICLE TYPE'), ('collided', 'REASON'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('56-year-old', 'AGE'), ('woman', 'GENDER'), ('four', 'INJURED'), ('Swift Dzire', 'VEHICLE TYPE'), ('collided', 'REASON'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four people, including a seven-year-old girl , were killed in two accidents since Thursday
# Predicted entities: [('Four', 'FATALITIES'), ('seven-year-old', 'AGE'), ('girl', 'GENDER')]
# Annotated entities: [('Four', 'FATALITIES'), ('seven-year-old', 'AGE'), ('girl', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A woman died and three others were severely injured after a speeding car rammed an APSRTC bus that was stationed at a bus stand at Jaggaiahpet in NTR district on Sunday morning
# Predicted entities: [('woman', 'GENDER'), ('three', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('woman', 'GENDER'), ('three', 'INJURED'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 30-year-old street vendor was killed while another was seriously injured when a speeding car rammed into them in Shalimar Bagh area of northwest Delhi, police said on Tuesday
# Predicted entities: [('30-year-old', 'AGE'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('30-year-old', 'AGE'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Two brothers travelling on a motorcycle died in a road accident on Chennai’s Kamarajar Salai on Sunday
# Predicted entities: [('Two', 'FATALITIES'), ('brothers', 'GENDER'), ('motorcycle', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('brothers', 'GENDER'), ('motorcycle', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A youth and his elder brother were killed when the motorcycle they were riding collided head on with a car on Saturday night near Hatli village of Chamba district
# Predicted entities: [('brother', 'GENDER'), ('motorcycle', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('brother', 'GENDER'), ('motorcycle', 'VEHICLE TYPE'), ('collided', 'REASON'), ('car', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.8
# Precision: 1.0
# Recall: 0.8
# F1-score: 0.888888888888889
# ---------------
# Text: A woman sub-inspector of Assam Police , who was in the news last year for arresting her fiance months before wedding for allegedly duping huge funds from two contractors in Majuli, was killed in a road accident under mysterious circumstances in Nagaon district after her car allegedly collided with a truck on NH-37 early on Tuesday, the police said
# Predicted entities: [('woman', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('early', 'TIME')]
# Annotated entities: [('woman', 'GENDER'), ('car', 'VEHICLE TYPE'), ('collided', 'REASON'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.6
# Precision: 0.75
# Recall: 0.75
# F1-score: 0.75
# ---------------
# Text: A 47-year-old policeman attached with the Pothanikkad police died in a vehicle accident on Saturday
# Predicted entities: [('47-year-old', 'AGE'), ('policeman', 'GENDER')]
# Annotated entities: [('47-year-old', 'AGE')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: A 19-year-old student driving a Mercedes, rammed into the rear-end of another car on Bandra-Worli sea link on Sunday
# Predicted entities: [('19-year-old', 'AGE'), ('Mercedes', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('19-year-old', 'AGE'), ('rammed', 'REASON'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.5
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1-score: 0.6666666666666666
# ---------------
# Text: Four passengers were killed when a car collided with a truck on National Highway-20 near Badapasi village in Keonjhar district on Thursday
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# ...
# Annotated entities: [('43-year-old', 'AGE'), ('autorickshaw', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Five people, including a mother-daughter duo, were killed in three separate accidents that occurred in Rudraprayag and Pithoragarh districts of Uttarakhand on Tuesday
# Predicted entities: [('Five', 'FATALITIES'), ('mother', 'AGE')]
# Annotated entities: [('Five people', 'FATALITIES'), ('mother-daughter', 'GENDER')]
# Accuracy: 0.0
# Precision: 0.0
# Recall: 0.0
# F1-score: 0
# ---------------
# Text: An IT employee died and three others suffered injuries on Thurday night after their car rammed a median near Potheri in Chengalpet
# Predicted entities: [('three', 'INJURED'), ('night', 'TIME'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('three', 'INJURED'), ('night', 'TIME'), ('car', 'VEHICLE TYPE'), ('rammed', 'REASON')]
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1-score: 0.8571428571428571
# ---------------
# Text: A 74-year-old man was crushed to death and his 67-year-old wife seriously injured when they were caught between their gate and their SUV after the driver pressed the accelerator instead of the brakes by mistake at Chromepet on Saturday night
# Predicted entities: [('74-year-old', 'AGE'), ('man', 'GENDER'), ('67-year-old', 'AGE'), ('wife', 'GENDER'), ('SUV', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('74-year-old', 'AGE'), ('man', 'GENDER'), ('67-year-old', 'AGE'), ('SUV', 'VEHICLE TYPE'), ('night', 'TIME')]
# Accuracy: 0.8333333333333334
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-score: 0.9090909090909091
# ---------------
# Text: Two assistant sub inspectors (ASIs) of police and a passerby were injured injuries after being hit by a car that overturned near Hilsa bypass on Thursday
# Predicted entities: [('Two', 'INJURED'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'INJURED'), ('car', 'VEHICLE TYPE'), ('overturned', 'REASON')]
# Accuracy: 0.6666666666666666
# Precision: 1.0
# Recall: 0.6666666666666666
# F1-score: 0.8
# ---------------
# Text: In a shocking incident, a car driver ran over a 35-year-old man and then volunteered to take him to hospital, but when the victim died on the way, he drove around for several hours before dumping the body in a canal
# Predicted entities: [('car', 'VEHICLE TYPE'), ('35-year-old', 'AGE'), ('man', 'GENDER')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('35-year-old', 'AGE'), ('man', 'GENDER')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A 27-year-old car mechanic died and two others were injured after a scooter and a bike collided head-on near Khandsa Chowk on Tuesday night
# Predicted entities: [('27-year-old', 'AGE'), ('car', 'VEHICLE TYPE'), ('two', 'INJURED'), ('scooter', 'VEHICLE TYPE'), ('bike', 'VEHICLE TYPE'), ('night', 'TIME')]
# Annotated entities: [('27-year-old', 'AGE'), ('car mechanic', 'VEHICLE TYPE'), ('two', 'INJURED'), ('scooter', 'VEHICLE TYPE'), ('bike', 'VEHICLE TYPE'), ('collided', 'REASON'), ('night', 'TIME')]
# Accuracy: 0.625
# Precision: 0.8333333333333334
# Recall: 0.7142857142857143
# F1-score: 0.7692307692307692
# ---------------
# Text: A 25-year-old man died after his speeding car rammed into a stationary truck on Thursday morning in the Surajpur area of Greater Noida
# Predicted entities: [('25-year-old', 'AGE'), ('man', 'GENDER'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('25-year-old', 'AGE'), ('man', 'GENDER'), ('car', 'VEHICLE TYPE'), ('rammed', 'REASON'), ('morning', 'TIME')]
# Accuracy: 0.5714285714285714
# Precision: 0.6666666666666666
# Recall: 0.8
# F1-score: 0.7272727272727272
# ---------------
# Text: A couple and their daughter died when a speeding car rammed a two-wheeler they were travelling on near Kondalampatty in Salem city on Tuesday
# Predicted entities: [('daughter', 'GENDER'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('two-wheeler', 'VEHICLE TYPE')]
# Annotated entities: [('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('two-wheeler', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 0.75
# Recall: 1.0
# F1-score: 0.8571428571428571
# ---------------
# Text: Eight people were injured — one of them seriously — after the car they were travelling in rammed into a tree on Elgin Road , Bhowanipore early on Friday
# Predicted entities: [('Eight', 'INJURED'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON')]
# Annotated entities: [('Eight', 'INJURED'), ('car', 'VEHICLE TYPE'), ('tree', 'REASON')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four people were killed in a collision between a car and a truck here on Wednesday, police said
# Predicted entities: [('Four', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('collision', 'REASON'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1-score: 0.8571428571428571
# ---------------
# Text: The Tambaram police have launched a search for a man who escaped from the Chromepet government hospital, where he was admitted by the police on Saturday night
# Predicted entities: [('man', 'GENDER'), ('night', 'TIME')]
# Annotated entities: [('man', 'GENDER'), ('night', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: A school teacher riding a bike was killed on the spot, and three persons critically injure after the two-wheeler collided with a speeding car in Farasgaon of Kondagaon district on Sunday morning
# Predicted entities: [('bike', 'VEHICLE TYPE'), ('three', 'INJURED'), ('two-wheeler', 'VEHICLE TYPE'), ('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('bike', 'VEHICLE TYPE'), ('three', 'INJURED'), ('two-wheeler', 'VEHICLE TYPE'), ('collided', 'REASON'), ('car', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# F1-score: 0.8333333333333334
# ---------------
# Text: Three persons, including a one-and-half year old girl, died after their car was hit by a lorry at Pinapaka on Friday afternoon
# Predicted entities: [('Three', 'FATALITIES'), ('one-and-half year old', 'AGE'), ('girl', 'GENDER'), ('car', 'VEHICLE TYPE'), ('lorry', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('one-and-half', 'AGE'), ('girl', 'GENDER'), ('car', 'VEHICLE TYPE'), ('lorry', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Accuracy: 0.7142857142857143
# Precision: 0.8333333333333334
# Recall: 0.8333333333333334
# F1-score: 0.8333333333333334
# ---------------
# Text: A 22-year-old youth was killed and two seriously injured when a four-wheeler they were travelling in overturned after being hit by another vehicle at Kanadia Bypass on Sunday morning
# Predicted entities: [('22-year-old', 'AGE'), ('two', 'INJURED'), ('four-wheeler', 'VEHICLE TYPE'), ('morning', 'TIME')]
# Annotated entities: [('22-year-old', 'AGE'), ('two', 'INJURED'), ('four-wheeler', 'VEHICLE TYPE'), ('overturned', 'REASON'), ('morning', 'TIME')]
# Accuracy: 0.8
# Precision: 1.0
# Recall: 0.8
# F1-score: 0.888888888888889
# ---------------
# Text: A 42-year-old man and a six-year-old child died in a road accident near Vataman Crossroads close to Bhalad village in Ahmedabad, when a truck rammed into their car on Thursday afternoon
# Predicted entities: [('42-year-old', 'AGE'), ('man', 'GENDER'), ('six-year-old', 'AGE'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Annotated entities: [('42-year-old', 'AGE'), ('man', 'GENDER'), ('six-year-old', 'AGE'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Ram Kinkar Ram, 35, the son of Trinamool councillor Ram Pyare Ram, was killed after a loaded truck toppled and fell on his car in the Kidderpore port area on Saturday evening
# Predicted entities: [('35', 'AGE'), ('son', 'GENDER'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('evening', 'TIME')]
# Annotated entities: [('35', 'AGE'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE'), ('evening', 'TIME')]
# Accuracy: 0.8
# Precision: 0.8
# Recall: 1.0
# F1-score: 0.888888888888889
# ---------------
# Text: A 35-year-old man died while three others sustained injuries on Saturday afternoon after a boulder fell from a hill onto their car around 2 km ahead of Kainchi Dham in Nainital
# Predicted entities: [('35-year-old', 'AGE'), ('man', 'GENDER'), ('three', 'INJURED'), ('afternoon', 'TIME'), ('boulder', 'REASON'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('35-year-old', 'AGE'), ('man', 'GENDER'), ('three', 'INJURED'), ('afternoon', 'TIME'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.8333333333333334
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-score: 0.9090909090909091
# ---------------
# Text: Two persons, including a woman, died and two others suffered injuries after the car they were travelling in from Bokaro collided with a JCB at Chutupalu valley on NH-33 near Maganpur village under Gola police police station limits on Saturday around 3
# Predicted entities: [('Two', 'FATALITIES'), ('woman', 'GENDER'), ('two', 'INJURED'), ('car', 'VEHICLE TYPE'), ('JCB', 'VEHICLE TYPE')]
# Annotated entities: [('Two', 'FATALITIES'), ('woman', 'GENDER'), ('two', 'INJURED'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.8
# Precision: 0.8
# Recall: 1.0
# F1-score: 0.888888888888889
# ---------------
# Text: A two-year-old boy, who was run over by a reversing car twice within a span of a few seconds, survived with grievous injuries at Pattanam near Rasipuram in the district on Saturday
# Predicted entities: [('two-year-old', 'AGE'), ('boy', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('two-year-old', 'AGE'), ('boy', 'GENDER'), ('car', 'VEHICLE TYPE')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Four persons, including a couple and their two minor daughters, were killed and another person was seriously injured on Sunday when a truck rammed into their car in Madhya Pradesh 's Sagar district , police said
# Predicted entities: [('Four', 'FATALITIES'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('truck', 'VEHICLE TYPE'), ('rammed', 'REASON'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1-score: 0.8571428571428571
# ---------------
# Text: A two-wheeler rider died after a KSRTC bus hit his vehicle at Jakribettu in Bantwal taluk on Wednesday
# Predicted entities: [('two-wheeler', 'VEHICLE TYPE'), ('bus', 'VEHICLE TYPE')]
# Annotated entities: [('two-wheeler', 'VEHICLE TYPE')]
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666
# ---------------
# Text: Three occupants of an Eeco van were killed and eight others were injured after their vehicle collided head on with a DTC bus on a flyover near Loni Gol Chakkar in northeast Delhi on Thursday afternoon
# Predicted entities: [('Three', 'FATALITIES'), ('Eeco', 'VEHICLE TYPE'), ('van', 'VEHICLE TYPE'), ('eight', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('van', 'VEHICLE TYPE'), ('eight', 'INJURED'), ('bus', 'VEHICLE TYPE'), ('afternoon', 'TIME')]
# Accuracy: 0.8333333333333334
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-score: 0.9090909090909091
# ---------------
# Text: Two days after a 25-year-old woman was killed when her shawl got entangled in the rear wheel of the bike she was riding pillion, the city traffic police on Friday requested women to be cautious while travelling on two-wheelers
# Predicted entities: [('25-year-old', 'AGE'), ('woman', 'GENDER'), ('shawl', 'VEHICLE TYPE'), ('bike', 'VEHICLE TYPE'), ('women', 'GENDER'), ('two-wheelers', 'VEHICLE TYPE')]
# Annotated entities: [('25-year-old', 'AGE'), ('woman', 'GENDER'), ('bike', 'VEHICLE TYPE'), ('women', 'GENDER'), ('two-wheelers', 'VEHICLE TYPE')]
# Accuracy: 0.8333333333333334
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-score: 0.9090909090909091
# ---------------
# Text: Three men lost their lives and one woman sustained injuries in Karauli on Wednesday when their car was hit by an oncoming truck
# Predicted entities: [('Three', 'FATALITIES'), ('men', 'GENDER'), ('one', 'INJURED'), ('woman', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Annotated entities: [('Three', 'FATALITIES'), ('men', 'GENDER'), ('woman', 'GENDER'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.8333333333333334
# Precision: 0.8333333333333334
# Recall: 1.0
# F1-score: 0.9090909090909091
# ---------------
# Text: A woman and three children were killed when a speeding canter truck rammed into a stationary car on the Delhi-Gurgaon Expressway near Jharsa Chowk, police said on Wednesday
# Predicted entities: [('woman', 'GENDER'), ('three', 'FATALITIES'), ('children', 'AGE'), ('speeding', 'REASON'), ('canter', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Annotated entities: [('woman', 'GENDER'), ('three', 'FATALITIES'), ('speeding', 'REASON'), ('truck', 'VEHICLE TYPE'), ('car', 'VEHICLE TYPE')]
# Accuracy: 0.7142857142857143
# Precision: 0.7142857142857143
# Recall: 1.0
# F1-score: 0.8333333333333333
# ---------------
# Text: Three people were killed and three others sustained injuries in a road accident on the outskirts of Kurnool city in Andhra Pradesh on Wednesday morning
# Predicted entities: [('Three', 'FATALITIES'), ('three', 'INJURED'), ('morning', 'TIME')]
# Annotated entities: [('Three', 'FATALITIES'), ('three', 'INJURED'), ('morning', 'TIME')]
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ---------------
# Text: Five members of a family died on the spot after their car hit a parked container truck on Pune-Bengaluru national highway on Saturday
# Predicted entities: [('Five', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('container truck', 'VEHICLE TYPE')]
# Annotated entities: [('Five', 'FATALITIES'), ('car', 'VEHICLE TYPE'), ('truck', 'VEHICLE TYPE')]
# Accuracy: 0.5
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1-score: 0.6666666666666666
# ---------------
# Text: A 28-year-old pedestrian died at a hospital after he was run over by a small cargo truck near the Sikanderpur Metro station on MG Road just after midnight on Monday
# Predicted entities: [('28-year-old', 'AGE'), ('cargo truck', 'VEHICLE TYPE'), ('midnight', 'TIME')]
# Annotated entities: [('28-year-old', 'AGE'), ('truck', 'VEHICLE TYPE'), ('midnight', 'TIME')]
# Accuracy: 0.5
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1-score: 0.6666666666666666
# ---------------
# Text: A luxury car caught fire and was almost completely charred after hitting a tree on Golf Course Road in the early hours of Thursday
# Predicted entities: [('car', 'VEHICLE TYPE'), ('tree', 'REASON')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('fire', 'REASON')]
# Accuracy: 0.3333333333333333
# Precision: 0.5
# Recall: 0.5
# F1-score: 0.5
# ---------------
# Text: A speeding rental car rammed into two policemen attached to the Verna police station on the Upasnagar-Sancoale highway
# Predicted entities: [('speeding', 'REASON'), ('car', 'VEHICLE TYPE'), ('two', 'INJURED'), ('policemen', 'GENDER')]
# Annotated entities: [('car', 'VEHICLE TYPE'), ('rammed', 'REASON')]
# Accuracy: 0.2
# Precision: 0.25
# Recall: 0.5
# F1-score: 0.3333333333333333
# ---------------
# Text: Four people were killed and three injured in a head-on collision between a car and a jeep in Rajasthan's Dausa district on Tuesday, police said
# Predicted entities: [('Four', 'FATALITIES'), ('three', 'INJURED'), ('head-on collision', 'REASON'), ('car', 'VEHICLE TYPE'), ('jeep', 'VEHICLE TYPE')]
# Annotated entities: [('Four', 'FATALITIES'), ('three', 'INJURED'), ('collision', 'REASON'), ('car', 'VEHICLE TYPE'), ('jeep', 'VEHICLE TYPE')]
# Accuracy: 0.6666666666666666
# Precision: 0.8
# Recall: 0.8
# F1-score: 0.8000000000000002
# ---------------
# Accuracy: 0.6666666666666666
# Average Precision: 0.8283858166922687
# Average Recall: 0.8534754224270354
# Average F1-score: 0.8275076178301987

# %%
import spacy
test_nlp = spacy.load('./output/spacy/model-best')

# %%
test_nlp.get_pipe('ner').labels
# Out:
# ('AGE', 'FATALITIES', 'GENDER', 'INJURED', 'REASON', 'TIME', 'VEHICLE TYPE')

# %%
# Read the live data that needs to be classified
df_livedata = pd.read_csv('raw_firstline.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Read the live data that needs to be classified
# ----> 2 df_livedata = pd.read_csv('raw_firstline.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'raw_firstline.csv'

# %%
def extract_article_id(url):
    match = re.search(r'\/(\d+)\.cms', url)
    if match:
        return int(match.group(1))
    else:
        return None

# %%
df_livedata['id'] = df_livedata['Link'].apply(extract_article_id)

# %%
# File path where the annotated IDs are stored
file_path = "id_list_annotated.txt"

# Reading the contents of the text file into a list
with open(file_path, 'r') as file:
    id_list_read = file.readlines()

# Removing newline characters from the elements of the list
id_list_read = [item.strip() for item in id_list_read]

# Converting the IDs from strings to integers
id_list_read = [int(x) for x in id_list_read]

# Creating a DataFrame from the list of IDs
id_df = pd.DataFrame(id_list_read, columns=['id'])

# %%
#Filter out the ids that have been used for training
df_livedata = df_livedata[~df_livedata['id'].isin(id_list_read)]

df_livedata = df_livedata[['id','content','First_Line']]  # Only filter out the id and the first line
