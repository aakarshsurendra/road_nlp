# %% [markdown]
# ## Column Transformations

# %%
pip install word2number
# Out:
# Requirement already satisfied: word2number in /Users/craigalbuquerque/anaconda3/lib/python3.11/site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import pandas as pd
import numpy as np
from word2number import w2n
import re

# %%
predictions=pd.read_csv("predictions.csv")

# %%
#Function to handle Age 
def extract_numeric_age(age_str):
    # Mapping of non-numeric age descriptors to a representative age
    age_descriptors = {'baby': 1, 'toddler': 2, 'children': 10, 'elderly': 70, 'middle-aged': 45,'teenager':13}
    numeric_ages = []    
    for part in age_str.lower().split(','):
        # Descriptor or month handling
        descriptor_handled = False
        for descriptor, age in age_descriptors.items():
            if descriptor in part:
                numeric_ages.append(age)
                descriptor_handled = True
        # Handle 'month-old' for fractional years if not already handled by descriptor
        if 'month-old' in part and not descriptor_handled:
            month_age = re.findall(r'\d+', part)
            if month_age:
                numeric_ages.append(round(int(month_age[0]) / 12.0,1))
            continue       
        # Extract numbers if part was not handled by descriptors or month-old logic
        if not descriptor_handled:
            try:
                age = w2n.word_to_num(part)
                numeric_ages.append(age)
            except ValueError:
                # Use regex to find numbers if word_to_num fails
                found_ages = re.findall(r'\d+', part)
                numeric_ages.extend([int(age) for age in found_ages])
    # Return appropriately based on the results
    return numeric_ages[0] if len(numeric_ages) == 1 else (numeric_ages if numeric_ages else 'na')

# %%
#Function to handle vehicle type
vehicle_mappings = {
    'Car': [ 'car', 'cars', 'suv', 'sedan', 'hatchback', 'toyota innova', 'hyundai creta','bmw', 'mercedes-benz', 'honda city', 'toyota qualis', 'swift dzire', 'jaguar car',
        'pcr van', 'mercedes', 'honda civic', 'innova car', 'maruti baleno', 'hyundai verna','fortuner', 'xuv', 'porsche', 'audi car', 'volkswagen polo', 'beetle car', 'baleno',
        'suzuki ertiga', 'renault car', 'ford', 'wagonr', 'tata nexon', 'bentley car','mercedes car', 'volvo car', 'range rover', 'bikes', 'mercedes-benz', 'swift car','biker', 
        'volkswagen', 'toyota sedan', 'innova-lorry', 'e-bus', 'honda', 'auto','luxury car', 'sports car', 'i10 car', 'toyota etios', 'ford mustang', 'ferrari car','eeco', 
        'hyundai grand', 'ford fiesta', 'jaguar', 'hyundai i10', 'honda civic','renault duster', 'toyota fortuner', 'mercedes benz', 'swift dzire'],
    'Two-Wheeler': ['bike', 'scooter', 'motorbike', 'bicycle', 'two-wheeler', 'scooty', 'biker', 'cyclist','motorcycle', 'bikes', 'minibus', 'minitruck', 'pickup', 'cycle', 'moped', 'bicycles','cyclists'],
    'Commercial Vehicle': ['truck', 'van', 'lorry', 'bus', 'goods carrier', 'tractor-trailer', 'mini-truck','pickup truck', 'container truck', 'dumper', 'tanker', 'canter', 'tempo', 'auto-rickshaw',
        'trolley', 'cargo truck', 'mini-bus', 'omnibus', 'cab', 'oil tanker', 'tanker truck','trailer truck', 'container-truck', 'pickup van', 'mini truck', 'tempo cruiser',
        'pickup', 'luxury bus', 'minibus', 'three wheeler', 'auto', 'rickshaw', 'e-rickshaw','autorickshaw', 'jeep', 'van', 'suv-borne', 'pickup truck', 'minivan', 'trailer',
        'bus-trailer', 'monobus', 'luxury bus', 'ambulance', 'police', 'land cruiser', 'defender','land rover', 'ambulance', 'fire truck', 'police van'],
    'Special Vehicle': ['tractor', 'jcb', 'road roller', 'earth mover', 'multi-utility vehicle', 'muv','multi-purpose vehicle', 'mpv', 'utility vehicle', 'erv', 'electric pole', 'earthmover',
        'crane', 'forklift', 'bulldozer', 'excavator', 'backhoe', 'dumper', 'loader']}
def categorize_vehicle_from_dict(vehicle_str):
    vehicle_str = vehicle_str.lower()
    categories = set()   
    # Extract vehicle terms from the string, handles lists and single entries
    vehicle_list = re.findall(r'[\w\s-]+', vehicle_str.replace('[', '').replace(']', ''))   
    # Identify categories for each vehicle term
    for v in vehicle_list:
        for category, keywords in vehicle_mappings.items():
            if any(keyword.lower() in v for keyword in keywords):
                categories.add(category)              
    return list(categories) if len(categories) > 1 else (categories.pop() if categories else 'na')

# %%
#Function to handle reason of accident
reason_mappings = {
    'Speed': ['speeding', 'speed', 'racing', 'joy'],
    'Alcohol': ['drunk', 'drunken', 'alcohol', 'drink'],
    'Collision': ['hit-and-run', 'collided', 'collision', 'mowing', 'mow', 'rammed'],
    'Visibility': ['fog', 'fogged', 'smog', 'light'],
    'Negligence': ['negligent', 'rash', 'reckless', 'dozed'],
    'Obstacle': ['tree', 'divider', 'rock', 'stones', 'brick'],
    'External influences': ['electric', 'electricity', 'drug', 'dementia', 'tyre', 'overloaded']
}
def categorize_accident_reason(reason_str):
    reason_str = reason_str.lower()
    categories = set()

    # Extract reason terms from the string, handling lists
    reason_list = re.findall(r'[\w-]+', reason_str.replace('[', '').replace(']', ''))
    
    # Identify categories for each reason term
    for reason in reason_list:
        for category, keywords in reason_mappings.items():
            if any(keyword in reason for keyword in keywords):
                categories.add(category)                
    return list(categories) if len(categories) > 1 else (categories.pop() if categories else 'na')

# %%
#Function to handle no of injured and fatalities
def text_to_single_number(text):
    try:
        return [w2n.word_to_num(item.strip()) for item in text.strip('[]').split(',')] if ',' in text or '[' in text else w2n.word_to_num(text)
    except ValueError:
        return 'na'

# %%
#Function to handle gender
male_keywords = {'man', 'men', 'boy', 'boys', 'son', 'sons', 'he', 'his', 'him', 'brother', 'brothers', 'father', 'grandfather', 'grandson', 'husband', 'businessman', 'businessmen', 'policeman', 'policemen', 'cameraman', 'male', 'nephew', 'uncle'}
female_keywords = {'woman', 'women', 'girl', 'girls', 'daughter', 'daughters', 'she', 'her', 'sister', 'sisters', 'mother', 'grandmother', 'granddaughter', 'wife', 'businesswoman', 'policewoman', 'female', 'niece', 'aunt', 'lady'}
def classify_gender(gender_str):
    tokens = set(re.split(r'[,\s\[\]]+', gender_str.lower()))
    identified_genders = []
    if any(token in male_keywords for token in tokens):
        identified_genders.append('Male')
    if any(token in female_keywords for token in tokens):
        identified_genders.append('Female')
    return identified_genders[0] if len(identified_genders) == 1 else identified_genders if identified_genders else 'na'

# %%
def categorize_time(time_str):
    # Keywords for categorizing times
    keywords = {
        'Morning': ['morning', 'am', 'dawn', 'predawn', 'early'],
        'Afternoon': ['afternoon', 'noon'],  # 'noon' generally considered part of afternoon
        'Evening': ['evening', 'late', 'dusk', 'sunset'],
        'Night': ['night', 'midnight', 'wee', 'late night']
    }
    # Split on commas, spaces, and brackets
    times = re.split(r'[\s,\[\]]+', time_str.lower())
    categories = set()
    for period, words in keywords.items():
        if any(word in time for time in times for word in words):
            categories.add(period)
    return categories.pop() if len(categories) == 1 else list(categories) if categories else 'na'

# %%
#Applying the funcitons to each columns
predictions['AGE'] = predictions['AGE'].apply(extract_numeric_age)

# %%
predictions['VEHICLE TYPE'] = predictions['VEHICLE TYPE'].apply(categorize_vehicle_from_dict)

# %%
predictions['REASON'] = predictions['REASON'].apply(categorize_accident_reason)

# %%
predictions['FATALITIES'] = predictions['FATALITIES'].apply(lambda x: text_to_single_number(x) if pd.notnull(x) else 'na')
predictions['INJURED'] = predictions['INJURED'].apply(lambda x: text_to_single_number(x) if pd.notnull(x) else 'na')

# %%
predictions['GENDER'] = predictions['GENDER'].apply(classify_gender)

# %%
predictions['TIME'] = predictions['TIME'].apply(categorize_time)

# %%
predictions.head(50)
# Out:
#     Unnamed: 0         ID                                            CONTENT  \
# 0            0   93122413  NEW DELHI: Three women from a family were kill...
# 1            1   93121445  NEW DELHI: Three women from a family were kill...
# 2            2  102292814  SURAT: Even as the public anger against speed ...
# 3            3   93097664  CHENNAI: A speeding car mowed down two people ...
# 4            4   99974120  Jaipur: A day after four persons were killed i...
# 5            5   94160142  PANAJI: Porvorim police on Monday registered a...
# 6            6   92630463  UDUPI: One person died and another person is r...
# 7            7   96099409  BELAGAVI: Two cars collided with each other le...
# 8            8  101003294  MUMBAI: The D B Marg police on Wednesday booke...
# 9            9  101427314  Pune: A five-year-old girl riding pillion with...
# 10          10  101552557  GURGAON: A 31-year-old director of a private f...
# 11          11   93655747  JAGDALPUR: Five men were killed after the car ...
# 12          12  102242880  Mandya: Four women died from drowning after th...
# 13          13  101413890  NASHIK: Four people were killed in an accident...
# 14          14   93978258  UTTARKASHI: A Dehradun man went missing while ...
# 15          15  102221262  GURGAON: A 24-year-old man died after a truck ...
# 16          16  100043859  PATNA: Five persons, including four members of...
# 17          17  101379388  Ludhiana: A 26-year-old man was killed on Thur...
# 18          18   90211528  Thiruvananthapuram: A 10-year-old boy, who was...
# 19          19  100025698  JAISALMER: Three persons died and six were inj...
# 20          20  101368828  TRICHY: Two people, including a six-year-old g...
# 21          21   99898366  HYDERABAD: One person died in a road accident ...
# 22          22   95288215  NOIDA: The wife of a former Waqf Board preside...
# 23          23  101621816  TIRUPATI : Six people were killed and one inju...
# 24          24  100907166  MUMBAI: Two men were killed while three of the...
# 25          25  100461799  Ludhiana: A day after the accident on Samrala ...
# 26          26  101323353  NOIDA: A 68-year-old woman and a 38-year-old m...
# 27          27   94492982  PANAJI: A mother and her son were killed in an...
# 28          28   93095907  YAMUNANAGAR: At least five Kanwar pilgrims wer...
# 29          29  101323738  Bhopal: A mother-son duo were killed while the...
# 30          30  101324242  Jammu: Five people died while 12 others were i...
# 31          31  101324772  Vadodara: A six-year-old boy returning from sc...
# 32          32  101320703  JAMMU: Five people died while 12 others were i...
# 33          33   99376226  KOLKATA: Four persons were killed in an accide...
# 34          34  101293078  KOLKATA: Sarala Rathi, 50, the only surviving ...
# 35          35   92804327  MUMBAI: The car in which rebel Shiv Sena MLA B...
# 36          36  100407662  VADODARA: In an accident that took place in Ka...
# 37          37  100925824  Prayagraj: Two persons including a property de...
# 38          38   99920845  NOIDA: A truck laden with iron pipes overturne...
# 39          39   92776304  VADODARA: A man in an inebriated condition das...
# 40          40  101266402  Hyderabad: One person died and another was inj...
# 41          41  100396175  JAIPUR: Three members of a family were killed ...
# 42          42  101266278  Noida: Three persons died after the SUV in whi...
# 43          43  101265009  NOIDA: Three persons died after the SUV in whi...
# 44          44   99104385  Mohali: A pregnant woman, Manpreet Kaur (25) o...
# 45          45  101250151  Bhopal: Two women were killed and two others w...
# 46          46   99328120  NAVI MUMBAI: Two children and a senior citizen...
# 47          47  101250102  Hyderabad: Boath MLA Rathod Bapu Rao had a nar...
# 48          48   92726768  HYDERABAD: A 19-year-old woman sustained serio...
# 49          49   89680655  HYDERABAD: Four persons travelling in a car we...
#
#                                            FIRST_LINE       AGE  \
# 0   Three women from a family were killed while tw...         1
# 1   Three women from a family were killed while tw...         1
# 2   Even as the public anger against speed demons ...        na
# 3   A speeding car mowed down two people boarding ...        na
# 4   A day after four persons were killed in a car ...        na
# 5   Porvorim police on Monday registered a case of...        na
# 6   One person died and another person is reported...        na
# 7   Two cars collided with each other leading to t...        na
# 8   The D B Marg police on Wednesday booked a 17-y...  [17, 13]
# 9   A five-year-old girl riding pillion with her 3...   [32, 5]
# 10  A 31-year-old director of a private firm was k...        31
# 11  Five men were killed after the car they were t...        na
# 12  Four women died from drowning after the vehicl...        na
# 13  Four people were killed in an accident involvi...        na
# 14  A Dehradun man went missing while another sust...        na
# 15  A 24-year-old man died after a truck allegedly...        24
# 16  Five persons, including four members of a fami...        na
# 17  A 26-year-old man was killed on Thursday, afte...        26
# 18  A 10-year-old boy, who was traveling with his ...        10
# 19  Three persons died and six were injured in two...        na
# 20  Two people, including a six-year-old girl, die...         6
# 21  One person died in a road accident on the bypa...        na
# 22  The wife of a former Waqf Board president in P...        na
# 23  Six people were killed and one injured in a ro...        na
# 24  Two men were killed while three of their frien...        na
# 25  A day after the accident on Samrala Road, in w...        na
# 26  A 68-year-old woman and a 38-year-old man died...  [68, 38]
# 27  A mother and her son were killed in an acciden...        na
# 28  At least five Kanwar pilgrims were hurt in an ...        na
# 29  A mother-son duo were killed while the the man...        12
# 30  Five people died while 12 others were injured ...        na
# 31  A six-year-old boy returning from school was k...         6
# 32  Five people died while 12 others were injured ...        na
# 33  Four persons were killed in an accident on VIP...        na
# 34  Sarala Rathi, 50, the only surviving member of...        50
# 35  The car in which rebel Shiv Sena MLA Bharat Go...        na
# 36  In an accident that took place in Karjan taluk...        na
# 37  Two persons including a property dealer were k...        na
# 38  A truck laden with iron pipes overturned near ...        25
# 39  A man in an inebriated condition dashed his ca...        na
# 40  One person died and another was injured after ...        na
# 41  Three members of a family were killed and as m...        na
# 42  Three persons died after the SUV in which they...        na
# 43  Three persons died after the SUV in which they...        na
# 44  A pregnant woman, Manpreet Kaur (25) of Phase ...        25
# 45  Two women were killed and two others were inju...        na
# 46  Two children and a senior citizen were killed,...        10
# 47  Boath MLA Rathod Bapu Rao had a narrow escape ...        na
# 48  A 19-year-old woman sustained serious injuries...        19
# 49  Four persons travelling in a car were killed a...        na
#
#                                   VEHICLE TYPE            REASON FATALITIES  \
# 0                    [Car, Commercial Vehicle]             Speed          3
# 1                    [Car, Commercial Vehicle]             Speed          3
# 2                           [Car, Two-Wheeler]  [Speed, Alcohol]         na
# 3                    [Car, Commercial Vehicle]             Speed         na
# 4                                          Car                na          4
# 5                                          Car        Negligence         na
# 6                                          Car                na          1
# 7                                          Car                na         na
# 8                           [Car, Two-Wheeler]                na          2
# 9                           [Car, Two-Wheeler]                na         na
# 10                                         Car                na         na
# 11                   [Car, Commercial Vehicle]                na          5
# 12                                          na                na          4
# 13                      [Car, Special Vehicle]                na          4
# 14                                         Car                na         na
# 15                   [Car, Commercial Vehicle]                na         na
# 16                   [Car, Commercial Vehicle]                na          5
# 17      [Car, Two-Wheeler, Commercial Vehicle]             Speed         na
# 18      [Car, Two-Wheeler, Commercial Vehicle]                na         na
# 19                                          na                na          3
# 20                          Commercial Vehicle                na          2
# 21                          [Car, Two-Wheeler]                na          1
# 22                          Commercial Vehicle                na         na
# 23                                          na                na          6
# 24                                         Car          Obstacle          2
# 25                                         Car                na          2
# 26                                          na                na         na
# 27                   [Car, Commercial Vehicle]                na         na
# 28                                         Car                na         na
# 29           [Two-Wheeler, Commercial Vehicle]             Speed         na
# 30                                          na                na          5
# 31                                          na                na         na
# 32                                          na                na          5
# 33      [Car, Two-Wheeler, Commercial Vehicle]                na          4
# 34                                         Car                na         na
# 35                                         Car                na         na
# 36                                          na                na         na
# 37  [Car, Special Vehicle, Commercial Vehicle]             Speed          2
# 38                          Commercial Vehicle                na         na
# 39                                         Car                na         na
# 40                                         Car           Alcohol          1
# 41                                         Car             Speed          3
# 42                                         Car                na          3
# 43                                         Car                na          3
# 44                   [Car, Commercial Vehicle]                na         na
# 45                   [Car, Commercial Vehicle]             Speed          2
# 46                   [Car, Commercial Vehicle]                na          2
# 47                                         Car          Obstacle         na
# 48                                         Car                na         na
# 49                   [Car, Commercial Vehicle]                na          4
#
#    INJURED          GENDER       TIME
# 0        2          Female         na
# 1        2          Female         na
# 2        5            Male      Night
# 3        2              na         na
# 4       na              na         na
# 5       na              na         na
# 6       na              na      Night
# 7       na  [Male, Female]      Night
# 8       na            Male    Morning
# 9       na  [Male, Female]         na
# 10      na              na         na
# 11      na            Male         na
# 12      na          Female         na
# 13      na              na    Evening
# 14      na            Male    Morning
# 15      na            Male      Night
# 16      na              na         na
# 17      na            Male         na
# 18      na            Male  Afternoon
# 19       6              na         na
# 20      11          Female         na
# 21      na              na         na
# 22       3          Female         na
# 23       1              na         na
# 24       3            Male    Morning
# 25       4              na         na
# 26      na  [Male, Female]         na
# 27      na  [Male, Female]         na
# 28       5              na    Evening
# 29      na            Male    Evening
# 30      12              na  Afternoon
# 31      na            Male         na
# 32      12              na  Afternoon
# 33      na              na      Night
# 34      na          Female    Morning
# 35      na              na    Morning
# 36      na            Male      Night
# 37      na              na      Night
# 38      na              na         na
# 39      na            Male         na
# 40      na            Male         na
# 41      na              na    Morning
# 42      na              na         na
# 43      na              na         na
# 44      na          Female         na
# 45       2          Female         na
# 46      na              na    Morning
# 47      na              na         na
# 48      na          Female         na
# 49      na              na    Morning

# %%
print('*'*20)
print('Percentage Missing')
print('*'*20)
for column in ['AGE', 'VEHICLE TYPE',
       'REASON', 'FATALITIES', 'INJURED', 'GENDER', 'TIME']:
    print('Column ('+ column + ('-') * (20 - len(column)) + '>' + str(predictions[predictions[column] == 'na'].shape[0]*100/predictions.shape[0]))
# Out:
# ********************
# Percentage Missing
# ********************
# Column (AGE----------------->72.78127183787561
# Column (VEHICLE TYPE-------->24.24877707896576
# Column (REASON-------------->77.30607966457023
# Column (FATALITIES---------->49.807826694619145
# Column (INJURED------------->68.16911250873515
# Column (GENDER-------------->65.07686932215235
# Column (TIME---------------->56.586303284416495
